# %% [markdown]
# - 학습시작일 : 2022년 04월 15일 - 16시 36분

# %% [markdown]
# # 02-1 데이터 집합 불러오기

# %% [markdown]
# ## 갭마인더 데이터 집합 불러오기

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/countifs/fork-doit_pandas/master/data/gapminder.tsv', sep='\t')

# %% [markdown]
# ## 불러온 데이터 집합 살펴보기

# %%
print(df.head())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.shape)
# Out:
# (1704, 6)

# %%
len(df)
# Out:
# 1704

# %%
print(df.columns)
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
print(df.dtypes)
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB
# None

# %% [markdown]
# # 02-2 데이터 추출하기

# %% [markdown]
# ### 열 단위로 데이터 추출하기

# %%
country_df = df['country']

# %%
print(type(country_df))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(country_df.head())
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
print(country_df.tail())
# Out:
# 1699    Zimbabwe
# 1700    Zimbabwe
# 1701    Zimbabwe
# 1702    Zimbabwe
# 1703    Zimbabwe
# Name: country, dtype: object

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
subset = df[['country', 'continent', 'year']]

# %%
print(subset.head())
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
print(subset.tail())
# Out:
#        country continent  year
# 1699  Zimbabwe    Africa  1987
# 1700  Zimbabwe    Africa  1992
# 1701  Zimbabwe    Africa  1997
# 1702  Zimbabwe    Africa  2002
# 1703  Zimbabwe    Africa  2007

# %% [markdown]
# ## loc 속성으로 행 데이터 추출하기

# %%
print(df.loc[0])
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
print(df.loc[99])
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
# print(df.loc[-1]) # 인덱스에 없는 값을 사용하면 오류 발생

# %%
df.shape
# Out:
# (1704, 6)

# %%
number_of_rows = df.shape[0]
last_row_index = number_of_rows - 1

# %%
print(df.loc[last_row_index])
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
print(df.loc[1703])
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
print(df.loc[1702])
# Out:
# country        Zimbabwe
# continent        Africa
# year               2002
# lifeExp          39.989
# pop            11926563
# gdpPercap    672.038623
# Name: 1702, dtype: object

# %%
print(df.tail(n=1))
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
print(df.loc[ [0, 99, 999] ] )
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
subset_loc = df.loc[0]
subset_tail = df.tail(n=1)

# %%
print(type(subset_loc))
print(type(subset_tail))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
subset_loc
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
subset_tail
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %% [markdown]
# ## iloc 속성으로 행 데이터 추출하기

# %%
print(df.iloc[1])
# Out:
# country      Afghanistan
# continent           Asia
# year                1957
# lifeExp           30.332
# pop              9240934
# gdpPercap      820.85303
# Name: 1, dtype: object

# %%
print(df.loc[1])
# Out:
# country      Afghanistan
# continent           Asia
# year                1957
# lifeExp           30.332
# pop              9240934
# gdpPercap      820.85303
# Name: 1, dtype: object

# %%
print(df.iloc[99])
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
print(df.iloc[-1])
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
print(df.iloc[ [ 0, 99, 999] ] )
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df.iloc[[0,99,999], 0:3]
# Out:
#          country continent  year
# 0    Afghanistan      Asia  1952
# 99    Bangladesh      Asia  1967
# 999     Mongolia      Asia  1967

# %%
df.iloc[ 0:5, 0:3 ]
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
df.iloc[ 0:5, [1,2,4] ]
# Out:
#   continent  year       pop
# 0      Asia  1952   8425333
# 1      Asia  1957   9240934
# 2      Asia  1962  10267083
# 3      Asia  1967  11537966
# 4      Asia  1972  13079460

# %%
df.iloc[0:6:2, [1,2,4]]
# Out:
#   continent  year       pop
# 0      Asia  1952   8425333
# 2      Asia  1962  10267083
# 4      Asia  1972  13079460

# %% [markdown]
# ## 데이터 추출하기 - 슬라이싱 구문, range 메서드

# %% [markdown]
# ### (1)  슬라이싱 구문으로 데이터 추출하기

# %%
subset = df.loc[:, ['year', 'pop'] ] 
print(subset.head() )
# Out:
#    year       pop
# 0  1952   8425333
# 1  1957   9240934
# 2  1962  10267083
# 3  1967  11537966
# 4  1972  13079460

# %%
subset = df.iloc[ : , [2, 4, -1] ]
print(subset.head())
# Out:
#    year       pop   gdpPercap
# 0  1952   8425333  779.445314
# 1  1957   9240934  820.853030
# 2  1962  10267083  853.100710
# 3  1967  11537966  836.197138
# 4  1972  13079460  739.981106

# %% [markdown]
# ### (2) range 메서드로 데이터 추출하기

# %%
small_range = list(range(5))
print(small_range)
# Out:
# [0, 1, 2, 3, 4]

# %%
print(type(small_range))
# Out:
# <class 'list'>

# %%
subset = df.iloc[ : , small_range]

# %%
print(subset.head())
# Out:
#        country continent  year  lifeExp       pop
# 0  Afghanistan      Asia  1952   28.801   8425333
# 1  Afghanistan      Asia  1957   30.332   9240934
# 2  Afghanistan      Asia  1962   31.997  10267083
# 3  Afghanistan      Asia  1967   34.020  11537966
# 4  Afghanistan      Asia  1972   36.088  13079460

# %%
small_range = list(range(3,6))
print(small_range)
# Out:
# [3, 4, 5]

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
len(df.columns)
# Out:
# 6

# %%
for i in range(len(df.columns)):
    print(i, df.columns[i], sep='\t')
# Out:
# 0	country
# 1	continent
# 2	year
# 3	lifeExp
# 4	pop
# 5	gdpPercap

# %%
subset = df.iloc[:, small_range]
print(subset.head())
# Out:
#    lifeExp       pop   gdpPercap
# 0   28.801   8425333  779.445314
# 1   30.332   9240934  820.853030
# 2   31.997  10267083  853.100710
# 3   34.020  11537966  836.197138
# 4   36.088  13079460  739.981106

# %%
small_range =  list(range(0, 6, 2))
subset = df.iloc[: , small_range]
print(subset.head())
# Out:
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 1  Afghanistan  1957   9240934
# 2  Afghanistan  1962  10267083
# 3  Afghanistan  1967  11537966
# 4  Afghanistan  1972  13079460

# %% [markdown]
# ### (4) 슬라이싱 구문과 range 매서드 비교하기

# %%
subset = df.iloc[:, :3]
print(subset.head())
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
subset = df.iloc[:, : : 2]

# %%
subset.head()
# Out:
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 1  Afghanistan  1957   9240934
# 2  Afghanistan  1962  10267083
# 3  Afghanistan  1967  11537966
# 4  Afghanistan  1972  13079460

# %% [markdown]
# ### loc, iloc속성 자유자재로 사용하기

# %%
print(df.iloc[ [0, 99, 999] , [0, 3, 5]] )
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %%
# print(df.iloc[ [0, 99, 999] , ['country', 'lifeExp'] ] )

# %% [markdown]
# <img src="https://slid-users-assets-v1-seoul.s3.ap-northeast-2.amazonaws.com/public/image_upload/e7ec0583b3904f57a348a10cbcbc680d/aeefe4b6-6b01-4492-bb69-80a3195bab79.png" alt="img" >
# <!--  (1) 크기조절 : ★height="00px" width="00px"★   (2)정렬 : ★align="right"★ -->

# %%
print(df.loc[[0, 99, 999], ['country', 'lifeExp', 'gdpPercap']])
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %%
print(df.loc[10:13, ['country', 'lifeExp', 'gdpPercap']])
# Out:
#         country  lifeExp    gdpPercap
# 10  Afghanistan   42.129   726.734055
# 11  Afghanistan   43.828   974.580338
# 12      Albania   55.230  1601.056136
# 13      Albania   59.280  1942.284244

# %%
print(df.loc[1:5, ['country', 'lifeExp']])
# Out:
#        country  lifeExp
# 1  Afghanistan   30.332
# 2  Afghanistan   31.997
# 3  Afghanistan   34.020
# 4  Afghanistan   36.088
# 5  Afghanistan   38.438

# %%
print(df.loc[ 1:5 ] ) # [ ] 하나로 들어가면 integer로 인식?
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360

# %%
print(df.iloc[1:5] )
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
subset = df.loc[ [2,3] ] # 숫자처럼 보였어도 string이였다. 
print(subset.head())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %%
print(df[ ['country', 'year'] ] )
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %%
df.iloc[1:4]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %%
df.loc[1:4]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %% [markdown]
# ### 기타

# %%
df2 = pd.DataFrame(
    { "bid_id": [1, 2, 3], 
     "bidder_id": ["Gadi", "Conda", "Lion"], 
     "city": ["Seoul", "LA", "Sydney"], 
     "item": ["TV", "jewelry", "book"]}).set_index("bid_id") 

df2
# Out:
#        bidder_id    city     item
# bid_id
# 1           Gadi   Seoul       TV
# 2          Conda      LA  jewelry
# 3           Lion  Sydney     book

# %%
df3 = pd.DataFrame(
    { "bid_id": [1, 2, 3], 
     "bidder_id": ["Gadi", "Conda", "Lion"], 
     "city": ["Seoul", "LA", "Sydney"], 
     "item": ["TV", "jewelry", "book"]})
df3
# Out:
#    bid_id bidder_id    city     item
# 0       1      Gadi   Seoul       TV
# 1       2     Conda      LA  jewelry
# 2       3      Lion  Sydney     book

# %% [markdown]
# # 02-3 기초적인 통계 계산하기

# %%
print(df.head(n=10))
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
print(df.groupby('year').mean())
# Out:
#         lifeExp           pop     gdpPercap
# year
# 1952  49.057620  1.695040e+07   3725.276046
# 1957  51.507401  1.876341e+07   4299.408345
# 1962  53.609249  2.042101e+07   4725.812342
# 1967  55.678290  2.265830e+07   5483.653047
# 1972  57.647386  2.518998e+07   6770.082815
# 1977  59.570157  2.767638e+07   7313.166421
# 1982  61.533197  3.020730e+07   7518.901673
# 1987  63.212613  3.303857e+07   7900.920218
# 1992  64.160338  3.599092e+07   8158.608521
# 1997  65.014676  3.883947e+07   9090.175363
# 2002  65.694923  4.145759e+07   9917.848365
# 2007  67.007423  4.402122e+07  11680.071820

# %%
grouped_year_df = df.groupby('year')
print(type(grouped_year_df))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
print(grouped_year_df)

# %%
grouped_year_df_lifeExp = grouped_year_df['lifeExp']
print(type(grouped_year_df_lifeExp))
# Out:
# <class 'pandas.core.groupby.generic.SeriesGroupBy'>

# %%
mean_lifeExp_by_year = grouped_year_df_lifeExp.mean()
print(mean_lifeExp_by_year)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df['continent'].head()
# Out:
# 0    Asia
# 1    Asia
# 2    Asia
# 3    Asia
# 4    Asia
# Name: continent, dtype: object

# %%
multi_group_var = df.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].mean()
print(multi_group_var)
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
print(df.groupby('continent')['country'].nunique())
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
print(df.groupby(['continent', 'country'])['country'].nunique())
# Out:
# continent  country
# Africa     Algeria           1
#            Angola            1
#            Benin             1
#            Botswana          1
#            Burkina Faso      1
#                             ..
# Europe     Switzerland       1
#            Turkey            1
#            United Kingdom    1
# Oceania    Australia         1
#            New Zealand       1
# Name: country, Length: 142, dtype: int64

# %% [markdown]
# # 02-4 그래프 그리기

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
global_yearly_life_expectancy = df.groupby('year')['lifeExp'].mean()
print(global_yearly_life_expectancy)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
global_yearly_life_expectancy.plot();
